# %% [markdown]
# <a href="https://colab.research.google.com/github/Adi1exe/Deep-learning-practicals/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Predicting if a person would buy life insurnace based on his age using logistic regression**
#
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a5ea6ed-92da-403a-a03c-1e5aa53602d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a5ea6ed-92da-403a-a03c-1e5aa53602d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(list(uploaded.keys())[0])

# %%
df
# Out:
#     age  affordibility  bought_insurance
# 0    22              1                 0
# 1    25              0                 0
# 2    47              1                 1
# 3    52              0                 0
# 4    46              1                 1
# 5    56              1                 1
# 6    55              0                 0
# 7    60              0                 1
# 8    62              1                 1
# 9    61              1                 1
# 10   18              1                 0
# 11   28              1                 0
# 12   27              0                 0
# 13   29              0                 0
# 14   49              1                 1
# 15   55              1                 1
# 16   25              0                 1
# 17   58              1                 1
# 18   19              0                 0
# 19   18              1                 0
# 20   21              1                 0
# 21   26              0                 0
# ...

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
df.shape
# Out:
# (28, 3)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 17   58
# 20   21
# 23   45
# 10   18
# 8    62
# 13   29

# %%
X_train
# Out:
#     age
# 16   25
# 21   26
# 0    22
# 15   55
# 27   46
# 3    52
# 1    25
# 22   40
# 4    46
# 26   23
# 6    55
# 2    47
# 7    60
# 19   18
# 24   50
# 12   27
# 9    61
# 5    56
# 25   54
# 14   49
# 18   19
# 11   28

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 17   58
# 20   21
# 23   45
# 10   18
# 8    62
# 13   29

# %%
y_test
# Out:
# 17    1
# 20    0
# 23    1
# 10    0
# 8     1
# 13    0
# Name: bought_insurance, dtype: int64

# %%
model.predict(X_test)
# Out:
# array([1, 0, 1, 0, 1, 0])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
X_test
# Out:
#     age
# 25   54
# 0    22
# 5    56
# 20   21
# 26   23
# 19   18

# %%
y_predicted = model.predict(X_test)

# %%
y_predicted
# Out:
# array([1, 0, 1, 0, 1, 0])

# %%
y_test
# Out:
# 25    1
# 0     0
# 5     1
# 20    0
# 26    0
# 19    0
# Name: bought_insurance, dtype: int64

# %%
model.predict_proba(X_test)
# Out:
# array([[0.12976176, 0.87023824],
#        [0.89788111, 0.10211889],
#        [0.38446973, 0.61553027],
#        [0.92445423, 0.07554577],
#        [0.08755824, 0.91244176],
#        [0.78455206, 0.21544794]])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
y_predicted
# Out:
# array([1, 0, 1, 0, 0, 0])

# %%
X_test
# Out:
#     age
# 14   49
# 25   54
# 16   25
# 8    62
# 15   55
# 2    47

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c181b04d-166d-4b28-a259-3009da2b59e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c181b04d-166d-4b28-a259-3009da2b59e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_csv(list(uploaded.keys())[0])
df1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# 1. Now do some exploratory data analysis to figure out which variables have direct and clear impact on employee retention (i.e. whether they leave the company or continue to work).
#
# 2. Plot bar charts showing impact of employee salaries on retention.
#
# 3. Plot bar charts showing corelation between department and employee retention.
#
# 4. Now build logistic regression model using variables that were narrowed down in step 1.
#
# 5. Measure the accuracy of the model
